# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('/content/homeprices.csv')

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(per ft)')
plt.ylabel('price(US$)')
plt.scatter(df.area, df.price, color ='r', marker= '*')
plt.plot(df.area,r.predict(df[['area']]),color = 'blue')

# %%
r = linear_model.LinearRegression()
r.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
df['area'].shape
# Out:
# (5,)

# %%
df.price.shape
# Out:
# (5,)

# %%
r.predict([[3500]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([655873.28767123])

# %% [markdown]
# <mark>
# Y = mx + b
#
# m = slope
#
# b = intercept
# </mark>

# %%
r.coef_
# Out:
# array([135.78767123])

# %%
r.intercept_
# Out:
# 180616.43835616432

# %%
y = 135.78767123*3500+180616.43835616432
y
# Out:
# 655873.2876611643

# %%
f = pd.read_csv('areas.csv')
f.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = r.predict(f)

# %%
f['prices'] = p

# %%
f
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
f.to_csv('predicted.csv')

# %%
ho = pd.read_csv('predicted.csv')

# %%
ho
# Out:
#     Unnamed: 0  area        prices
# 0            0  1000  3.164041e+05
# 1            1  1500  3.842979e+05
# 2            2  2300  4.929281e+05
# 3            3  3540  6.613048e+05
# 4            4  4120  7.400616e+05
# 5            5  4560  7.998082e+05
# 6            6  5490  9.260908e+05
# 7            7  3460  6.504418e+05
# 8            8  4750  8.256079e+05
# 9            9  2300  4.929281e+05
# 10          10  9000  1.402705e+06
# 11          11  8600  1.348390e+06
# 12          12  7100  1.144709e+06

# %%
ex = pd.read_csv('/content/canada_per_capita_income.csv')
ex
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
ex.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
r.fit(ex[['year']], ex['per capita income (US$)'])
r.predict([[2020]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
